# %%
import pandas as pd
import math

# %%
df = pd.read_csv('musics-csv.csv')
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.725   0.622    7    -5.573     0       0.0438        0.5790
# 1           0.641   0.613   11    -5.386     1       0.0302        0.4070
# 2           0.685   0.457    4    -4.957     1       0.0468        0.7550
# 3           0.501   0.407    4   -13.691     1       0.1090        0.0264
# 4           0.672   0.594    9    -7.300     0       0.2670        0.0848
# ..            ...     ...  ...       ...   ...          ...           ...
# 208         0.427   0.817    3    -5.196     1       0.0385        0.0445
# 209         0.727   0.801    7    -5.104     0       0.0285        0.3150
# 210         0.653   0.726    5   -10.288     1       0.0465        0.4030
# 211         0.813   0.731    4    -5.557     1       0.0436        0.6120
# 212         0.502   0.967    7    -4.140     1       0.0801        0.0122
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
for x in range(len(df.columns)):
    column=df[df.columns[x]]
    desvio=column.std(axis=None)
    err=desvio/math.sqrt(len(column))
    intervalo=err*1.96
    print(df.columns[x],"\nmin",column.mean()-intervalo,"max",column.mean()+intervalo)
# Out:
# danceability
# min 0.6183174218650814 max 0.6546215452710683
# energy
# min 0.633961727330569 max 0.6907490707914957
# key
# min 4.751283062638308 max 5.746369519521316
# loudness
# min -7.2564591027546195 max -6.375108972362754
# mode
# min 0.49661654513832143 max 0.6301440182419603
# speechiness
# min 0.10883168225458208 max 0.1384819327688921
# acousticness
# min 0.29050325864628346 max 0.36713916388892764
# instrumentalness
# min 0.0 max 0.0
# liveness
# min 0.25142828173797094 max 0.3230759436141415
# valence
# min 0.5135548955254388 max 0.581379376775031
# tempo
# min 121.3201367400417 max 128.79148767310375
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
# ...
